# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sc
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('D:\УНИВЕРСИТЕТ\Дополнительные дела\хакатон Норка\df_hack_final.csv')

# %%
data.isna().sum().hist()
# Out:
# <Axes: >

# %%
pd.set_option('display.max_columns', None)

# %%
data.head()
# Out:
#                MEAS_DT  Cu_oreth  Ni_oreth  Ore_mass       Mass_1      Mass_2  \
# 0  2024-01-01 00:00:00    2.6097    1.5313    1096.5  1240.597656  692.090942
# 1  2024-01-01 00:15:00    2.5548    1.4842    1123.0  1205.422363  693.616394
# 2  2024-01-01 00:30:00    2.5109    1.4355     840.0  1188.762573  698.350586
# 3  2024-01-01 00:45:00    2.4765    1.3852     824.0  1151.888672  714.678101
# 4  2024-01-01 01:00:00    2.3585    1.3368       0.0  1104.101318  730.190674
#
#      Dens_4      Mass_4       Vol_4   Cu_4F   Ni_4F  Ni_4.1C  Ni_4.1C_max  \
# 0  1.342155  711.999023  1548.71875  0.6232  2.4937   4.1826          NaN
# 1  1.339809  710.697815  1556.56250  0.6292  2.5157   4.1037          4.7
# 2  1.339792  707.198547  1548.09375  0.5941  2.5253   4.1911          4.7
# 3  1.342392  707.865540  1538.87500  0.6682  2.5418   4.1268          4.7
# 4  1.337608  700.935059  1545.18750  0.6489  2.5559   4.1805          4.7
#
#    Ni_4.1C_min  Ni_4.1T  Ni_4.1T_max  Ni_4.1T_min  FM_4.1_A  Ni_4.2C  \
# 0          NaN   0.7136          NaN          NaN       NaN   3.8121
# 1          4.5   0.7247         0.77         0.67       0.0   3.7383
# 2          4.5   0.7069         0.77         0.67       0.0   3.7132
# 3          4.5   0.7097         0.77         0.67       0.0   3.7086
# 4          4.5   0.7155         0.77         0.67       0.0   3.7558
#
#    Ni_4.2C_max  Ni_4.2C_min  Ni_4.2T  Ni_4.2T_max  Ni_4.2T_min  FM_4.2_A  \
# 0          NaN          NaN   0.7602          NaN          NaN       NaN
# 1          4.7          4.2   0.7585         0.75         0.68       0.0
# 2          4.7          4.2   0.7613         0.75         0.68       0.0
# 3          4.7          4.2   0.7412         0.75         0.68       0.0
# 4          4.7          4.2   0.7550         0.75         0.68       0.0
#
#      Dens_5      Mass_5        Vol_5    Ni_5F  Ni_5.1C  Ni_5.1C_max  \
# 0  1.346855  476.127625  1021.624939  3.99735   6.2100          NaN
# 1  1.342700  473.042267  1027.312500  3.92100   6.3300          6.5
# 2  1.342700  472.912659  1026.937500  3.95215   6.2619          6.5
# 3  1.342075  475.598877  1034.750000  3.91770   6.0307          6.5
# 4  1.340294  473.865509  1036.375000  3.96815   6.0333          6.5
#
#    Ni_5.1C_min  Ni_5.1T  Ni_5.1T_max  Ni_5.1T_min  FM_5.1_A  Ni_5.2C  \
# 0          NaN   0.7943          NaN          NaN       NaN   6.7906
# 1          6.3   0.8009         0.75         0.68       0.0   6.6420
# 2          6.3   0.7829         0.75         0.68       0.0   6.5325
# 3          6.3   0.7576         0.75         0.68       0.0   6.7853
# 4          6.3   0.7486         0.75         0.68       0.0   6.7513
#
#    Ni_5.2C_max  Ni_5.2C_min  Ni_5.2T  Ni_5.2T_max  Ni_5.2T_min  FM_5.2_A  \
# 0          NaN          NaN   0.7694          NaN          NaN       NaN
# 1          6.5          6.3   0.7743         0.75         0.65       0.0
# 2          6.5          6.3   0.7582         0.75         0.65       0.0
# 3          6.5          6.3   0.7656         0.75         0.65       0.0
# 4          6.5          6.3   0.7583         0.75         0.65       0.0
#
#      Dens_6      Mass_6      Vol_6    Ni_6F  Ni_6.1C  Ni_6.1C_max  \
# 0  1.344661  219.958878  474.96875  9.09595   9.0939          NaN
# 1  1.335838  275.753723  611.09375  9.02795   9.0422          9.5
# 2  1.312747  263.925659  626.93750  8.95510   8.9666          9.5
# 3  1.317930  250.852905  586.18750  8.93175   8.9439          9.5
# 4  1.311027  256.771332  615.59375  9.08420   9.1168          9.5
#
#    Ni_6.1C_min  Ni_6.1T  Ni_6.1T_max  Ni_6.1T_min  FM_6.1_A  Ni_6.2C  \
# 0          NaN   1.3531          NaN          NaN       NaN   9.0980
# 1          9.0   1.3338         1.45          1.4       0.0   9.0137
# 2          9.0   1.2827         1.45          1.4       0.0   8.9436
# 3          9.0   1.3131         1.45          1.4       0.0   8.9196
# 4          9.0   1.3491         1.45          1.4       0.0   9.0516
#
#    Ni_6.2C_max  Ni_6.2C_min  Ni_6.2T  Ni_6.2T_max  Ni_6.2T_min  FM_6.2_A  \
# 0          NaN          NaN   1.2932          NaN          NaN       NaN
# 1          9.5          9.0   1.3044          1.5          1.4       0.0
# 2          9.5          9.0   1.2598          1.5          1.4       0.0
# 3          9.5          9.0   1.3118          1.5          1.4       0.0
# 4          9.5          9.0   1.4647          1.5          1.4       0.0
#
#    Cu_resth  Ni_resth  Cu_1.1C  Ni_1.1C  Cu_1.2C  Ni_1.2C   Cu_2F   Ni_2F  \
# 0    1.8008    8.2067   4.4612   2.5949   5.0066   2.9721  4.5836  2.7272
# 1    1.8160    7.8830   4.5157   2.5875   5.1750   3.0450  4.4472  2.7258
# 2    1.9386    7.7173   4.4968   2.6646   5.1975   3.0923  4.4774  2.7327
# 3    2.0530    7.8480   4.5375   2.6634   4.7779   2.8601  4.4943  2.7428
# 4    2.1132    7.9884   4.5612   2.6661   4.7434   2.8084  4.4985  2.7503
#
#    Cu_2.1C  Ni_2.1C  Cu_2.2C  Ni_2.2C    Cu_3F   Ni_3F  Cu_3.1C  Ni_3.1C  \
# 0  18.0072   2.8705  17.5073   2.5247  13.5003  2.8885  14.3382   2.8217
# 1  18.1457   2.8092  17.4514   2.4793  13.4167  2.9271  14.1753   2.8282
# 2  16.3150   2.7114  17.3994   2.4534  13.6483  2.8914  13.9210   2.8325
# 3  13.4985   2.8692  18.0951   2.4767  13.2095  3.0479  13.7438   2.8401
# 4  13.8650   2.7396  17.7093   2.4251  13.2739  3.0288  13.7098   2.7849
#
#    Cu_3.2C  Ni_3.2C  Cu_2.1T  Ni_2.1T  Cu_2.2T  Ni_2.2T  Cu_3.1T  Ni_3.1T  \
# 0  14.9352   2.7402   0.6405   2.0980   0.4005   2.7056   1.6723   3.9535
# 1  14.6916   2.7704   0.6740   2.0389   0.3986   2.7757   1.4766   3.9686
# 2  14.5276   2.7553   0.7055   2.0604   0.3968   2.7219   1.2512   4.0164
# 3  14.1897   2.8553   0.6965   2.0800   0.3964   2.7827   0.9814   3.9514
# 4  14.4848   2.7443   0.7043   2.0787   0.4000   2.7358   0.8553   3.9408
#
#    Cu_3.2T  Ni_3.2T    Dens_3    Dens_1    Dens_2       Mass_3  FM_1.1_A  \
# 0   1.7310   4.4555  0.808328  1.388724  1.397016  1159.946120       NaN
# 1   1.8037   4.2734  0.807156  1.375562  1.397872  1189.409024       0.0
# 2   1.6489   4.4432  0.797312  1.371214  1.399892  1247.048316       0.0
# 3   1.3331   4.4488  0.791000  1.374260  1.408990  1323.884446       0.0
# 4   1.3668   4.4291  0.799141  1.357874  1.414643  1295.851179       0.0
#
#    Cu_1.1C_max  Cu_1.1C_min  Ni_1.1C_max  Ni_1.1C_min  Ni_1.1T_max  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          5.0          4.7          3.2          2.7         0.15
# 2          5.0          4.7          3.2          2.7         0.15
# 3          5.0          4.7          3.2          2.7         0.15
# 4          5.0          4.7          3.2          2.7         0.15
#
#    Ni_1.1T_min  FM_1.2_A  Cu_1.2C_max  Cu_1.2C_min  Ni_1.2C_max  Ni_1.2C_min  \
# 0          NaN       NaN          NaN          NaN          NaN          NaN
# 1         0.12       0.0          5.0          4.7          3.2          2.7
# 2         0.12       0.0          5.0          4.7          3.2          2.7
# 3         0.12       0.0          5.0          4.7          3.2          2.7
# 4         0.12       0.0          5.0          4.7          3.2          2.7
#
#    Ni_1.2T_max  Ni_1.2T_min  FM_2.1_A  Cu_2.1C_max  Cu_2.1C_min  Cu_2.1T_max  \
# 0          NaN          NaN       NaN          NaN          NaN          NaN
# 1         0.15         0.12       0.0         17.0         16.0         0.45
# 2         0.15         0.12       0.0         17.0         16.0         0.45
# 3         0.15         0.12       0.0         17.0         16.0         0.45
# 4         0.15         0.12       0.0         17.0         16.0         0.45
#
#    Cu_2.1T_min  FM_2.2_A  Cu_2.2C_max  Cu_2.2C_min  Cu_2.2T_max  Cu_2.2T_min  \
# 0          NaN       NaN          NaN          NaN          NaN          NaN
# 1         0.34       0.0         17.0         16.0         0.42         0.34
# 2         0.34       0.0         17.0         16.0         0.42         0.34
# 3         0.34       0.0         17.0         16.0         0.42         0.34
# 4         0.34       0.0         17.0         16.0         0.42         0.34
#
#    FM_3.1_A  Cu_3.1C_max  Cu_3.1C_min  Ni_3.1C_max  Ni_3.1C_min  Cu_3.1T_max  \
# 0       NaN          NaN          NaN          NaN          NaN          NaN
# 1       0.0         15.5         14.5          3.9          3.7          1.0
# 2       0.0         15.5         14.5          3.9          3.7          1.0
# 3       0.0         15.5         14.5          3.9          3.7          1.0
# 4       0.0         15.5         14.5          3.9          3.7          1.0
#
#    Cu_3.1T_min  FM_3.2_A  Cu_3.2C_max  Cu_3.2C_min  Ni_3.2C_max  Ni_3.2C_min  \
# 0          NaN       NaN          NaN          NaN          NaN          NaN
# 1          0.8       0.0         14.0         12.0          3.7          3.5
# 2          0.8       0.0         14.0         12.0          3.7          3.5
# 3          0.8       0.0         14.0         12.0          3.7          3.5
# 4          0.8       0.0         14.0         12.0          3.7          3.5
#
#    Cu_3.2T_max  Cu_3.2T_min    Ni_rec
# 0          NaN          NaN       NaN
# 1          1.2          1.0       NaN
# 2          1.2          1.0  0.970170
# 3          1.2          1.0  0.968639
# 4          1.2          1.0  0.974205

# %%
data['MEAS_DT'] = pd.to_datetime(data['MEAS_DT'])
data['MEAS_DT'] = data['MEAS_DT'].apply(lambda x: x.timestamp())

# %%
data.head()
# Out:
#         MEAS_DT  Cu_oreth  Ni_oreth  Ore_mass       Mass_1      Mass_2  \
# 0  1.704067e+09    2.6097    1.5313    1096.5  1240.597656  692.090942
# 1  1.704068e+09    2.5548    1.4842    1123.0  1205.422363  693.616394
# 2  1.704069e+09    2.5109    1.4355     840.0  1188.762573  698.350586
# 3  1.704070e+09    2.4765    1.3852     824.0  1151.888672  714.678101
# 4  1.704071e+09    2.3585    1.3368       0.0  1104.101318  730.190674
#
#      Dens_4      Mass_4       Vol_4   Cu_4F   Ni_4F  Ni_4.1C  Ni_4.1C_max  \
# 0  1.342155  711.999023  1548.71875  0.6232  2.4937   4.1826          NaN
# 1  1.339809  710.697815  1556.56250  0.6292  2.5157   4.1037          4.7
# 2  1.339792  707.198547  1548.09375  0.5941  2.5253   4.1911          4.7
# 3  1.342392  707.865540  1538.87500  0.6682  2.5418   4.1268          4.7
# 4  1.337608  700.935059  1545.18750  0.6489  2.5559   4.1805          4.7
#
#    Ni_4.1C_min  Ni_4.1T  Ni_4.1T_max  Ni_4.1T_min  FM_4.1_A  Ni_4.2C  \
# 0          NaN   0.7136          NaN          NaN       NaN   3.8121
# 1          4.5   0.7247         0.77         0.67       0.0   3.7383
# 2          4.5   0.7069         0.77         0.67       0.0   3.7132
# 3          4.5   0.7097         0.77         0.67       0.0   3.7086
# 4          4.5   0.7155         0.77         0.67       0.0   3.7558
#
#    Ni_4.2C_max  Ni_4.2C_min  Ni_4.2T  Ni_4.2T_max  Ni_4.2T_min  FM_4.2_A  \
# 0          NaN          NaN   0.7602          NaN          NaN       NaN
# 1          4.7          4.2   0.7585         0.75         0.68       0.0
# 2          4.7          4.2   0.7613         0.75         0.68       0.0
# 3          4.7          4.2   0.7412         0.75         0.68       0.0
# 4          4.7          4.2   0.7550         0.75         0.68       0.0
#
#      Dens_5      Mass_5        Vol_5    Ni_5F  Ni_5.1C  Ni_5.1C_max  \
# 0  1.346855  476.127625  1021.624939  3.99735   6.2100          NaN
# 1  1.342700  473.042267  1027.312500  3.92100   6.3300          6.5
# 2  1.342700  472.912659  1026.937500  3.95215   6.2619          6.5
# 3  1.342075  475.598877  1034.750000  3.91770   6.0307          6.5
# 4  1.340294  473.865509  1036.375000  3.96815   6.0333          6.5
#
#    Ni_5.1C_min  Ni_5.1T  Ni_5.1T_max  Ni_5.1T_min  FM_5.1_A  Ni_5.2C  \
# 0          NaN   0.7943          NaN          NaN       NaN   6.7906
# 1          6.3   0.8009         0.75         0.68       0.0   6.6420
# 2          6.3   0.7829         0.75         0.68       0.0   6.5325
# 3          6.3   0.7576         0.75         0.68       0.0   6.7853
# 4          6.3   0.7486         0.75         0.68       0.0   6.7513
#
#    Ni_5.2C_max  Ni_5.2C_min  Ni_5.2T  Ni_5.2T_max  Ni_5.2T_min  FM_5.2_A  \
# 0          NaN          NaN   0.7694          NaN          NaN       NaN
# 1          6.5          6.3   0.7743         0.75         0.65       0.0
# 2          6.5          6.3   0.7582         0.75         0.65       0.0
# 3          6.5          6.3   0.7656         0.75         0.65       0.0
# 4          6.5          6.3   0.7583         0.75         0.65       0.0
#
#      Dens_6      Mass_6      Vol_6    Ni_6F  Ni_6.1C  Ni_6.1C_max  \
# 0  1.344661  219.958878  474.96875  9.09595   9.0939          NaN
# 1  1.335838  275.753723  611.09375  9.02795   9.0422          9.5
# 2  1.312747  263.925659  626.93750  8.95510   8.9666          9.5
# 3  1.317930  250.852905  586.18750  8.93175   8.9439          9.5
# 4  1.311027  256.771332  615.59375  9.08420   9.1168          9.5
#
#    Ni_6.1C_min  Ni_6.1T  Ni_6.1T_max  Ni_6.1T_min  FM_6.1_A  Ni_6.2C  \
# 0          NaN   1.3531          NaN          NaN       NaN   9.0980
# 1          9.0   1.3338         1.45          1.4       0.0   9.0137
# 2          9.0   1.2827         1.45          1.4       0.0   8.9436
# 3          9.0   1.3131         1.45          1.4       0.0   8.9196
# 4          9.0   1.3491         1.45          1.4       0.0   9.0516
#
#    Ni_6.2C_max  Ni_6.2C_min  Ni_6.2T  Ni_6.2T_max  Ni_6.2T_min  FM_6.2_A  \
# 0          NaN          NaN   1.2932          NaN          NaN       NaN
# 1          9.5          9.0   1.3044          1.5          1.4       0.0
# 2          9.5          9.0   1.2598          1.5          1.4       0.0
# 3          9.5          9.0   1.3118          1.5          1.4       0.0
# 4          9.5          9.0   1.4647          1.5          1.4       0.0
#
#    Cu_resth  Ni_resth  Cu_1.1C  Ni_1.1C  Cu_1.2C  Ni_1.2C   Cu_2F   Ni_2F  \
# 0    1.8008    8.2067   4.4612   2.5949   5.0066   2.9721  4.5836  2.7272
# 1    1.8160    7.8830   4.5157   2.5875   5.1750   3.0450  4.4472  2.7258
# 2    1.9386    7.7173   4.4968   2.6646   5.1975   3.0923  4.4774  2.7327
# 3    2.0530    7.8480   4.5375   2.6634   4.7779   2.8601  4.4943  2.7428
# 4    2.1132    7.9884   4.5612   2.6661   4.7434   2.8084  4.4985  2.7503
#
#    Cu_2.1C  Ni_2.1C  Cu_2.2C  Ni_2.2C    Cu_3F   Ni_3F  Cu_3.1C  Ni_3.1C  \
# 0  18.0072   2.8705  17.5073   2.5247  13.5003  2.8885  14.3382   2.8217
# 1  18.1457   2.8092  17.4514   2.4793  13.4167  2.9271  14.1753   2.8282
# 2  16.3150   2.7114  17.3994   2.4534  13.6483  2.8914  13.9210   2.8325
# 3  13.4985   2.8692  18.0951   2.4767  13.2095  3.0479  13.7438   2.8401
# 4  13.8650   2.7396  17.7093   2.4251  13.2739  3.0288  13.7098   2.7849
#
#    Cu_3.2C  Ni_3.2C  Cu_2.1T  Ni_2.1T  Cu_2.2T  Ni_2.2T  Cu_3.1T  Ni_3.1T  \
# 0  14.9352   2.7402   0.6405   2.0980   0.4005   2.7056   1.6723   3.9535
# 1  14.6916   2.7704   0.6740   2.0389   0.3986   2.7757   1.4766   3.9686
# 2  14.5276   2.7553   0.7055   2.0604   0.3968   2.7219   1.2512   4.0164
# 3  14.1897   2.8553   0.6965   2.0800   0.3964   2.7827   0.9814   3.9514
# 4  14.4848   2.7443   0.7043   2.0787   0.4000   2.7358   0.8553   3.9408
#
#    Cu_3.2T  Ni_3.2T    Dens_3    Dens_1    Dens_2       Mass_3  FM_1.1_A  \
# 0   1.7310   4.4555  0.808328  1.388724  1.397016  1159.946120       NaN
# 1   1.8037   4.2734  0.807156  1.375562  1.397872  1189.409024       0.0
# 2   1.6489   4.4432  0.797312  1.371214  1.399892  1247.048316       0.0
# 3   1.3331   4.4488  0.791000  1.374260  1.408990  1323.884446       0.0
# 4   1.3668   4.4291  0.799141  1.357874  1.414643  1295.851179       0.0
#
#    Cu_1.1C_max  Cu_1.1C_min  Ni_1.1C_max  Ni_1.1C_min  Ni_1.1T_max  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          5.0          4.7          3.2          2.7         0.15
# 2          5.0          4.7          3.2          2.7         0.15
# 3          5.0          4.7          3.2          2.7         0.15
# 4          5.0          4.7          3.2          2.7         0.15
#
#    Ni_1.1T_min  FM_1.2_A  Cu_1.2C_max  Cu_1.2C_min  Ni_1.2C_max  Ni_1.2C_min  \
# 0          NaN       NaN          NaN          NaN          NaN          NaN
# 1         0.12       0.0          5.0          4.7          3.2          2.7
# 2         0.12       0.0          5.0          4.7          3.2          2.7
# 3         0.12       0.0          5.0          4.7          3.2          2.7
# 4         0.12       0.0          5.0          4.7          3.2          2.7
#
#    Ni_1.2T_max  Ni_1.2T_min  FM_2.1_A  Cu_2.1C_max  Cu_2.1C_min  Cu_2.1T_max  \
# 0          NaN          NaN       NaN          NaN          NaN          NaN
# 1         0.15         0.12       0.0         17.0         16.0         0.45
# 2         0.15         0.12       0.0         17.0         16.0         0.45
# 3         0.15         0.12       0.0         17.0         16.0         0.45
# 4         0.15         0.12       0.0         17.0         16.0         0.45
#
#    Cu_2.1T_min  FM_2.2_A  Cu_2.2C_max  Cu_2.2C_min  Cu_2.2T_max  Cu_2.2T_min  \
# 0          NaN       NaN          NaN          NaN          NaN          NaN
# 1         0.34       0.0         17.0         16.0         0.42         0.34
# 2         0.34       0.0         17.0         16.0         0.42         0.34
# 3         0.34       0.0         17.0         16.0         0.42         0.34
# 4         0.34       0.0         17.0         16.0         0.42         0.34
#
#    FM_3.1_A  Cu_3.1C_max  Cu_3.1C_min  Ni_3.1C_max  Ni_3.1C_min  Cu_3.1T_max  \
# 0       NaN          NaN          NaN          NaN          NaN          NaN
# 1       0.0         15.5         14.5          3.9          3.7          1.0
# 2       0.0         15.5         14.5          3.9          3.7          1.0
# 3       0.0         15.5         14.5          3.9          3.7          1.0
# 4       0.0         15.5         14.5          3.9          3.7          1.0
#
#    Cu_3.1T_min  FM_3.2_A  Cu_3.2C_max  Cu_3.2C_min  Ni_3.2C_max  Ni_3.2C_min  \
# 0          NaN       NaN          NaN          NaN          NaN          NaN
# 1          0.8       0.0         14.0         12.0          3.7          3.5
# 2          0.8       0.0         14.0         12.0          3.7          3.5
# 3          0.8       0.0         14.0         12.0          3.7          3.5
# 4          0.8       0.0         14.0         12.0          3.7          3.5
#
#    Cu_3.2T_max  Cu_3.2T_min    Ni_rec
# 0          NaN          NaN       NaN
# 1          1.2          1.0       NaN
# 2          1.2          1.0  0.970170
# 3          1.2          1.0  0.968639
# 4          1.2          1.0  0.974205

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30336 entries, 0 to 30335
# Columns: 130 entries, MEAS_DT to Ni_rec
# dtypes: float64(130)
# memory usage: 30.1 MB

# %%
data.Ni_rec.hist()
# Out:
# <Axes: >

# %%
data.isna().sum()
# Out:
# MEAS_DT           0
# Cu_oreth       4123
# Ni_oreth       4123
# Ore_mass          0
# Mass_1            0
#                ...
# Ni_3.2C_max       1
# Ni_3.2C_min       1
# Cu_3.2T_max       1
# Cu_3.2T_min       1
# Ni_rec         2577
# Length: 130, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30336 entries, 0 to 30335
# Columns: 130 entries, MEAS_DT to Ni_rec
# dtypes: float64(130)
# memory usage: 30.1 MB

# %%
data.dropna(subset = 'Cu_oreth', inplace = True)       
data.dropna(subset = 'Ni_rec',inplace = True)

# %%
data.isna().sum()
# Out:
# MEAS_DT        0
# Cu_oreth       0
# Ni_oreth       0
# Ore_mass       0
# Mass_1         0
#               ..
# Ni_3.2C_max    0
# Ni_3.2C_min    0
# Cu_3.2T_max    0
# Cu_3.2T_min    0
# Ni_rec         0
# Length: 130, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25460 entries, 2 to 30335
# Columns: 130 entries, MEAS_DT to Ni_rec
# dtypes: float64(130)
# memory usage: 25.4 MB

# %%
# Построение графика
plt.figure(figsize=(10, 6))
# График Y1
plt.plot(data['Ni_4.1C_max'], data['Ni_4.1C_min'], marker='o', label='Y1', color='blue')

# # График Y2
# plt.plot(data['X'], data['Y2'], marker='o', label='Y2', color='green')

# # График Y3
# plt.plot(data['X'], data['Y3'], marker='o', label='Y3', color='red')

# %%
rec_stats = data['Ni_rec'].describe()

# Check for missing values in the target variable
rec_missing = data['Ni_rec'].isnull().sum()

rec_stats, rec_missing
# Out:
# (count    25460.000000
#  mean         0.947612
#  std          0.020732
#  min          0.594336
#  25%          0.933534
#  50%          0.943713
#  75%          0.965939
#  max          1.000000
#  Name: Ni_rec, dtype: float64,
#  0)

# %%
data['Ni_rec'].isna().sum()
# Out:
# 0

# %%
# Определяем столбцы с пропусками
columns_with_nan = data.columns[data.isna().any()]

# Создаем новый DataFrame с этими столбцами
data_with_nan_columns = data[columns_with_nan]

# %%
data_with_nan_columns.head()
# Out:
#     Cu_4F   Ni_4F  Ni_4.1C  Ni_4.1T  Ni_4.2C  Ni_4.2T    Ni_5F  Ni_5.1C  \
# 2  0.5941  2.5253   4.1911   0.7069   3.7132   0.7613  3.95215   6.2619
# 3  0.6682  2.5418   4.1268   0.7097   3.7086   0.7412  3.91770   6.0307
# 4  0.6489  2.5559   4.1805   0.7155   3.7558   0.7550  3.96815   6.0333
# 5  0.6562  2.5664   4.1513   0.7078   3.7298   0.7344  3.94055   6.1412
# 6  0.6130  2.6006   4.1347   0.7197   3.7561   0.7570  3.94540   6.0178
#
#    Ni_5.1T  Ni_5.2C  Ni_5.2T    Ni_6F  Ni_6.1C  Ni_6.1T  Ni_6.2C  Ni_6.2T  \
# 2   0.7829   6.5325   0.7582  8.95510   8.9666   1.2827   8.9436   1.2598
# 3   0.7576   6.7853   0.7656  8.93175   8.9439   1.3131   8.9196   1.3118
# 4   0.7486   6.7513   0.7583  9.08420   9.1168   1.3491   9.0516   1.4647
# 5   0.7445   6.7406   0.7650  9.25035   9.3767   1.3733   9.1240   1.4941
# 6   0.7430   6.7126   0.7561  9.27635   9.4228   1.3966   9.1299   1.4994
#
#    Cu_1.1C  Ni_1.1C  Cu_1.2C  Ni_1.2C   Cu_2F   Ni_2F  Cu_2.1C  Ni_2.1C  \
# 2   4.4968   2.6646   5.1975   3.0923  4.4774  2.7327  16.3150   2.7114
# 3   4.5375   2.6634   4.7779   2.8601  4.4943  2.7428  13.4985   2.8692
# 4   4.5612   2.6661   4.7434   2.8084  4.4985  2.7503  13.8650   2.7396
# 5   4.5591   2.6527   4.6999   2.8032  4.4614  2.7401  13.6774   2.7929
# 6   4.5882   2.4969   4.7658   2.8417  4.5221  2.7504  14.0141   2.7539
#
#    Cu_2.2C  Ni_2.2C    Cu_3F   Ni_3F  Cu_3.1C  Ni_3.1C  Cu_3.2C  Ni_3.2C  \
# 2  17.3994   2.4534  13.6483  2.8914  13.9210   2.8325  14.5276   2.7553
# 3  18.0951   2.4767  13.2095  3.0479  13.7438   2.8401  14.1897   2.8553
# 4  17.7093   2.4251  13.2739  3.0288  13.7098   2.7849  14.4848   2.7443
# 5  17.8943   2.4067  13.4554  3.1502  13.6002   2.8521  14.1745   2.7956
# 6  17.4454   2.4594  13.0283  3.0218  13.5630   2.8776  14.4655   2.7608
#
#    Cu_2.1T  Ni_2.1T  Cu_2.2T  Ni_2.2T  Cu_3.1T  Ni_3.1T  Cu_3.2T  Ni_3.2T
# 2   0.7055   2.0604   0.3968   2.7219   1.2512   4.0164   1.6489   4.4432
# 3   0.6965   2.0800   0.3964   2.7827   0.9814   3.9514   1.3331   4.4488
# 4   0.7043   2.0787   0.4000   2.7358   0.8553   3.9408   1.3668   4.4291
# 5   0.7068   2.0443   0.4001   2.7679   0.8759   3.8894   1.5237   4.4957
# 6   0.6814   2.0860   0.4039   2.7813   0.9157   3.9096   1.4510   4.4319

# %%
isna_df = pd.DataFrame(data_with_nan_columns.isna().sum()/25460, columns=['NaN_%'] )

# %%
isna_df
# Out:
#             NaN_%
# Cu_4F    0.030911
# Ni_4F    0.030911
# Ni_4.1C  0.005460
# Ni_4.1T  0.005106
# Ni_4.2C  0.148704
# Ni_4.2T  0.147800
# Ni_5F    0.153181
# Ni_5.1C  0.008602
# Ni_5.1T  0.145758
# Ni_5.2C  0.012451
# Ni_5.2T  0.004203
# Ni_6F    0.076316
# Ni_6.1C  0.007973
# Ni_6.1T  0.008877
# Ni_6.2C  0.069717
# Ni_6.2T  0.089356
# Cu_1.1C  0.155538
# Ni_1.1C  0.155538
# Cu_1.2C  0.015593
# Ni_1.2C  0.015593
# Cu_2F    0.153024
# Ni_2F    0.153024
# Cu_2.1C  0.071210
# Ni_2.1C  0.071210
# Cu_2.2C  0.013668
# Ni_2.2C  0.013668
# Cu_3F    0.181422
# Ni_3F    0.181422
# Cu_3.1C  0.152042
# Ni_3.1C  0.152042
# Cu_3.2C  0.002632
# Ni_3.2C  0.002632
# Cu_2.1T  0.146426
# Ni_2.1T  0.146426
# Cu_2.2T  0.149568
# Ni_2.2T  0.149568
# Cu_3.1T  0.150157
# Ni_3.1T  0.150157
# Cu_3.2T  0.007266
# Ni_3.2T  0.007266

# %%
isna_df_Mean = isna_df[isna_df['NaN_%'] < 0.05 ].index

# %%
isna_df_5proc = isna_df[isna_df['NaN_%'] >= 0.05 ]

# %%
isna_df_5proc.index
# Out:
# Index(['Ni_4.2C', 'Ni_4.2T', 'Ni_5F', 'Ni_5.1T', 'Ni_6F', 'Ni_6.2C', 'Ni_6.2T',
#        'Cu_1.1C', 'Ni_1.1C', 'Cu_2F', 'Ni_2F', 'Cu_2.1C', 'Ni_2.1C', 'Cu_3F',
#        'Ni_3F', 'Cu_3.1C', 'Ni_3.1C', 'Cu_2.1T', 'Ni_2.1T', 'Cu_2.2T',
#        'Ni_2.2T', 'Cu_3.1T', 'Ni_3.1T'],
#       dtype='object')

# %%
isna_df_5proc_list = isna_df_5proc.index

# %%
isna_df_5proc_list
# Out:
# Index(['Ni_4.2C', 'Ni_4.2T', 'Ni_5F', 'Ni_5.1T', 'Ni_6F', 'Ni_6.2C', 'Ni_6.2T',
#        'Cu_1.1C', 'Ni_1.1C', 'Cu_2F', 'Ni_2F', 'Cu_2.1C', 'Ni_2.1C', 'Cu_3F',
#        'Ni_3F', 'Cu_3.1C', 'Ni_3.1C', 'Cu_2.1T', 'Ni_2.1T', 'Cu_2.2T',
#        'Ni_2.2T', 'Cu_3.1T', 'Ni_3.1T'],
#       dtype='object')

# %%
corr_map = {}
for feat in isna_df_5proc_list:
    target_feature = feat # Укажите имя признака, для которого ищем коррелирующие признаки
    correlations = data.corr()[target_feature]
    high_corr_features = correlations[abs(correlations) > 0.5].index.tolist()
    corr_map[feat] = high_corr_features

# %%
for feat in corr_map:
    print(feat, len(corr_map[feat]))
# Out:
# Ni_4.2C 2
# Ni_4.2T 3
# Ni_5F 3
# Ni_5.1T 4
# Ni_6F 7
# Ni_6.2C 9
# Ni_6.2T 13
# Cu_1.1C 1
# Ni_1.1C 1
# Cu_2F 1
# Ni_2F 2
# Cu_2.1C 6
# Ni_2.1C 6
# Cu_3F 6
# Ni_3F 8
# Cu_3.1C 3
# Ni_3.1C 5
# Cu_2.1T 22
# Ni_2.1T 4
# Cu_2.2T 8
# Ni_2.2T 19
# Cu_3.1T 1
# Ni_3.1T 5

# %%
data['Cu_3F'].min()
# Out:
# 6.7375

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures



def fill_NaN(data,feature,corr_list):
    for feat in isna_df_Mean:
        data[feat].fillna(data[feat].median(),inplace = True)   
    if len(corr_list) == 1:
        data[feature].fillna(data[feature].median(), inplace=True)
    else:
        train_data = data[data[feature].notna()]
        missing_data = data[data[feature].isna()] 

        X_train = train_data[corr_list]  # Используем только выбранные признаки
        X_train.fillna(X_train.median(),inplace=True)
        # print(X_train.isna().sum())
        y_train = train_data[feature]  # Целевая переменная

        X_missing = missing_data[corr_list]  # Данные с пропусками для предсказания
        X_missing.fillna(X_train.median(), inplace=True)

        # Создаем полиномиальные признаки
        degree = 2  # Степень полинома
        poly = PolynomialFeatures(degree)
        X_train_poly = poly.fit_transform(X_train)
        X_missing_poly = poly.transform(X_missing)

        # Обучаем модель
        model = LinearRegression()
        model.fit(X_train_poly, y_train)

        predicted_values = model.predict(X_missing_poly)



        data.loc[data[feature].isna(), feature] = predicted_values

# %%
# Определяем столбцы с пропусками
columns_with_nan = data.columns[data.isna().any()]

# Создаем новый DataFrame с этими столбцами
data_with_nan_columns = data[columns_with_nan]

# %%
for feat in isna_df_5proc_list:
    fill_NaN(data,feat,corr_map[feat])
# Out:
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)

# %%
# #['Ni_4.2C', 'Ni_4.2T', 'Ni_5F', 'Ni_5.1T', 'Ni_6F', 'Ni_6.2C', 'Ni_6.2T',
#        'Cu_1.1C', 'Ni_1.1C', 'Cu_2F', 'Ni_2F', 'Cu_2.1C', 'Ni_2.1C', 'Cu_3F',
#        'Ni_3F', 'Cu_3.1C', 'Ni_3.1C', 'Cu_2.1T', 'Ni_2.1T', 'Cu_2.2T',
#        'Ni_2.2T', 'Cu_3.1T', 'Ni_3.1T']

from sklearn.metrics import mean_squared_error, mean_absolute_error
data_copy = data.copy()

feat_metrix_map = {}

for test_feat in isna_df_5proc_list:
    # Искусственно создаем пропуски в части данных
    test_indices = data_copy.sample(frac=0.1, random_state=42).index
    data_copy.loc[test_indices, test_feat] = None  # Убираем значения

    # Заполняем пропуски с помощью модели
    fill_NaN(data_copy, test_feat, corr_map[test_feat])

    # Сравниваем предсказанные значения с исходными
    predicted_values = data_copy.loc[test_indices, test_feat]
    true_values = data.loc[test_indices, test_feat]

    # Метрики качества
    mse = mean_squared_error(true_values, predicted_values)
    mae = mean_absolute_error(true_values, predicted_values)
    feat_metrix_map[test_feat] = [mse,mae]
# Out:
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.fillna(X_train.median(),inplace=True)
# C:\Users\CKM\AppData\Local\Temp\ipykernel_4808\4240682860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_missing.fillna(X_train.median(), inplace=True)

# %%
for feat in feat_metrix_map:
    print(f"{feat}: {feat_metrix_map[feat][0]}, {feat_metrix_map[feat][1]}")
# Out:
# Ni_4.2C: 0.09636973183425021, 0.22360357423409355
# Ni_4.2T: 0.00656696815003918, 0.044490691280441017
# Ni_5F: 0.054119407034024215, 0.18122826728483293
# Ni_5.1T: 0.0016177573055774132, 0.02773731343283661
# Ni_6F: 0.08994377131170397, 0.23061146897094895
# Ni_6.2C: 0.06971221563030063, 0.19941941390414483
# Ni_6.2T: 0.05904739371312391, 0.18751700032498667
# Cu_1.1C: 0.04698495670070699, 0.14982513747054205
# Ni_1.1C: 0.08227433148075414, 0.20677073841319718
# Cu_2F: 0.1362794407148468, 0.2679747054202671
# Ni_2F: 0.013626008444617806, 0.089719324430484
# Cu_2.1C: 0.9022369673723426, 0.7009152003142824
# Ni_2.1C: 0.17642014963864006, 0.28872623723488333
# Cu_3F: 3.0636880577926595, 1.19311445404562
# Ni_3F: 0.22220268350746203, 0.30126492537315647
# Cu_3.1C: 1.967931298860932, 0.9609501963865255
# Ni_3.1C: 0.09422292638649091, 0.1866810683424998
# Cu_2.1T: 0.003775185258798666, 0.046117728411364876
# Ni_2.1T: 0.06972040676649735, 0.18918407305577672
# Cu_2.2T: 0.004705558266611452, 0.04622271585975924
# Ni_2.2T: 0.03147135239160196, 0.14299883930821686
# Cu_3.1T: 0.31593817492144544, 0.335252120974077
# Ni_3.1T: 0.377973138150035, 0.3636818931657518

# %%
data.head()
# Out:
#         MEAS_DT  Cu_oreth  Ni_oreth  Ore_mass       Mass_1      Mass_2  \
# 2  1.704069e+09    2.5109    1.4355     840.0  1188.762573  698.350586
# 3  1.704070e+09    2.4765    1.3852     824.0  1151.888672  714.678101
# 4  1.704071e+09    2.3585    1.3368       0.0  1104.101318  730.190674
# 5  1.704072e+09    2.3672    1.3081     781.0  1077.806885  738.083862
# 6  1.704073e+09    2.4030    1.3266     992.0  1056.742554  737.300171
#
#      Dens_4      Mass_4       Vol_4   Cu_4F   Ni_4F  Ni_4.1C  Ni_4.1C_max  \
# 2  1.339792  707.198547  1548.09375  0.5941  2.5253   4.1911          4.7
# 3  1.342392  707.865540  1538.87500  0.6682  2.5418   4.1268          4.7
# 4  1.337608  700.935059  1545.18750  0.6489  2.5559   4.1805          4.7
# 5  1.336420  697.026794  1542.00000  0.6562  2.5664   4.1513          4.7
# 6  1.333465  690.764038  1541.68750  0.6130  2.6006   4.1347          4.7
#
#    Ni_4.1C_min  Ni_4.1T  Ni_4.1T_max  Ni_4.1T_min  FM_4.1_A  Ni_4.2C  \
# 2          4.5   0.7069         0.77         0.67       0.0   3.7132
# 3          4.5   0.7097         0.77         0.67       0.0   3.7086
# 4          4.5   0.7155         0.77         0.67       0.0   3.7558
# 5          4.5   0.7078         0.77         0.67       0.0   3.7298
# 6          4.5   0.7197         0.77         0.67       0.0   3.7561
#
#    Ni_4.2C_max  Ni_4.2C_min  Ni_4.2T  Ni_4.2T_max  Ni_4.2T_min  FM_4.2_A  \
# 2          4.7          4.2   0.7613         0.75         0.68       0.0
# 3          4.7          4.2   0.7412         0.75         0.68       0.0
# 4          4.7          4.2   0.7550         0.75         0.68       0.0
# 5          4.7          4.2   0.7344         0.75         0.68       0.0
# 6          4.7          4.2   0.7570         0.75         0.68       0.0
#
#      Dens_5      Mass_5      Vol_5    Ni_5F  Ni_5.1C  Ni_5.1C_max  \
# 2  1.342700  472.912659  1026.9375  3.95215   6.2619          6.5
# 3  1.342075  475.598877  1034.7500  3.91770   6.0307          6.5
# 4  1.340294  473.865509  1036.3750  3.96815   6.0333          6.5
# 5  1.343883  453.330566   982.8125  3.94055   6.1412          6.5
# 6  1.337854  455.175110  1002.6875  3.94540   6.0178          6.5
#
#    Ni_5.1C_min  Ni_5.1T  Ni_5.1T_max  Ni_5.1T_min  FM_5.1_A  Ni_5.2C  \
# 2          6.3   0.7829         0.75         0.68       0.0   6.5325
# 3          6.3   0.7576         0.75         0.68       0.0   6.7853
# 4          6.3   0.7486         0.75         0.68       0.0   6.7513
# 5          6.3   0.7445         0.75         0.68       0.0   6.7406
# 6          6.3   0.7430         0.75         0.68       0.0   6.7126
#
#    Ni_5.2C_max  Ni_5.2C_min  Ni_5.2T  Ni_5.2T_max  Ni_5.2T_min  FM_5.2_A  \
# 2          6.5          6.3   0.7582         0.75         0.65       0.0
# 3          6.5          6.3   0.7656         0.75         0.65       0.0
# 4          6.5          6.3   0.7583         0.75         0.65       0.0
# 5          6.5          6.3   0.7650         0.75         0.65       0.0
# 6          6.5          6.3   0.7561         0.75         0.65       0.0
#
#      Dens_6      Mass_6      Vol_6    Ni_6F  Ni_6.1C  Ni_6.1C_max  \
# 2  1.312747  263.925659  626.93750  8.95510   8.9666          9.5
# 3  1.317930  250.852905  586.18750  8.93175   8.9439          9.5
# 4  1.311027  256.771332  615.59375  9.08420   9.1168          9.5
# 5  1.310433  253.524994  607.81250  9.25035   9.3767          9.5
# 6  1.310464  253.793915  609.50000  9.27635   9.4228          9.5
#
#    Ni_6.1C_min  Ni_6.1T  Ni_6.1T_max  Ni_6.1T_min  FM_6.1_A  Ni_6.2C  \
# 2          9.0   1.2827         1.45          1.4       0.0   8.9436
# 3          9.0   1.3131         1.45          1.4       0.0   8.9196
# 4          9.0   1.3491         1.45          1.4       0.0   9.0516
# 5          9.0   1.3733         1.45          1.4       0.0   9.1240
# 6          9.0   1.3966         1.45          1.4       0.0   9.1299
#
#    Ni_6.2C_max  Ni_6.2C_min  Ni_6.2T  Ni_6.2T_max  Ni_6.2T_min  FM_6.2_A  \
# 2          9.5          9.0   1.2598          1.5          1.4       0.0
# 3          9.5          9.0   1.3118          1.5          1.4       0.0
# 4          9.5          9.0   1.4647          1.5          1.4       0.0
# 5          9.5          9.0   1.4941          1.5          1.4       0.0
# 6          9.5          9.0   1.4994          1.5          1.4       0.0
#
#    Cu_resth  Ni_resth  Cu_1.1C  Ni_1.1C  Cu_1.2C  Ni_1.2C   Cu_2F   Ni_2F  \
# 2    1.9386    7.7173   4.4968   2.6646   5.1975   3.0923  4.4774  2.7327
# 3    2.0530    7.8480   4.5375   2.6634   4.7779   2.8601  4.4943  2.7428
# 4    2.1132    7.9884   4.5612   2.6661   4.7434   2.8084  4.4985  2.7503
# 5    2.1552    8.0598   4.5591   2.6527   4.6999   2.8032  4.4614  2.7401
# 6    2.1975    8.2045   4.5882   2.4969   4.7658   2.8417  4.5221  2.7504
#
#    Cu_2.1C  Ni_2.1C  Cu_2.2C  Ni_2.2C    Cu_3F   Ni_3F  Cu_3.1C  Ni_3.1C  \
# 2  16.3150   2.7114  17.3994   2.4534  13.6483  2.8914  13.9210   2.8325
# 3  13.4985   2.8692  18.0951   2.4767  13.2095  3.0479  13.7438   2.8401
# 4  13.8650   2.7396  17.7093   2.4251  13.2739  3.0288  13.7098   2.7849
# 5  13.6774   2.7929  17.8943   2.4067  13.4554  3.1502  13.6002   2.8521
# 6  14.0141   2.7539  17.4454   2.4594  13.0283  3.0218  13.5630   2.8776
#
#    Cu_3.2C  Ni_3.2C  Cu_2.1T  Ni_2.1T  Cu_2.2T  Ni_2.2T  Cu_3.1T  Ni_3.1T  \
# 2  14.5276   2.7553   0.7055   2.0604   0.3968   2.7219   1.2512   4.0164
# 3  14.1897   2.8553   0.6965   2.0800   0.3964   2.7827   0.9814   3.9514
# 4  14.4848   2.7443   0.7043   2.0787   0.4000   2.7358   0.8553   3.9408
# 5  14.1745   2.7956   0.7068   2.0443   0.4001   2.7679   0.8759   3.8894
# 6  14.4655   2.7608   0.6814   2.0860   0.4039   2.7813   0.9157   3.9096
#
#    Cu_3.2T  Ni_3.2T    Dens_3    Dens_1    Dens_2       Mass_3  FM_1.1_A  \
# 2   1.6489   4.4432  0.797312  1.371214  1.399892  1247.048316       0.0
# 3   1.3331   4.4488  0.791000  1.374260  1.408990  1323.884446       0.0
# 4   1.3668   4.4291  0.799141  1.357874  1.414643  1295.851179       0.0
# 5   1.5237   4.4957  0.799125  1.350775  1.409509  1342.597612       0.0
# 6   1.4510   4.4319  0.796609  1.342155  1.406083  1396.324873       0.0
#
#    Cu_1.1C_max  Cu_1.1C_min  Ni_1.1C_max  Ni_1.1C_min  Ni_1.1T_max  \
# 2          5.0          4.7          3.2          2.7         0.15
# 3          5.0          4.7          3.2          2.7         0.15
# 4          5.0          4.7          3.2          2.7         0.15
# 5          5.0          4.7          3.2          2.7         0.15
# 6          5.0          4.7          3.2          2.7         0.15
#
#    Ni_1.1T_min  FM_1.2_A  Cu_1.2C_max  Cu_1.2C_min  Ni_1.2C_max  Ni_1.2C_min  \
# 2         0.12       0.0          5.0          4.7          3.2          2.7
# 3         0.12       0.0          5.0          4.7          3.2          2.7
# 4         0.12       0.0          5.0          4.7          3.2          2.7
# 5         0.12       0.0          5.0          4.7          3.2          2.7
# 6         0.12       0.0          5.0          4.7          3.2          2.7
#
#    Ni_1.2T_max  Ni_1.2T_min  FM_2.1_A  Cu_2.1C_max  Cu_2.1C_min  Cu_2.1T_max  \
# 2         0.15         0.12       0.0         17.0         16.0         0.45
# 3         0.15         0.12       0.0         17.0         16.0         0.45
# 4         0.15         0.12       0.0         17.0         16.0         0.45
# 5         0.15         0.12       0.0         17.0         16.0         0.45
# 6         0.15         0.12       0.0         17.0         16.0         0.45
#
#    Cu_2.1T_min  FM_2.2_A  Cu_2.2C_max  Cu_2.2C_min  Cu_2.2T_max  Cu_2.2T_min  \
# 2         0.34       0.0         17.0         16.0         0.42         0.34
# 3         0.34       0.0         17.0         16.0         0.42         0.34
# 4         0.34       0.0         17.0         16.0         0.42         0.34
# 5         0.34       0.0         17.0         16.0         0.42         0.34
# 6         0.34       0.0         17.0         16.0         0.42         0.34
#
#    FM_3.1_A  Cu_3.1C_max  Cu_3.1C_min  Ni_3.1C_max  Ni_3.1C_min  Cu_3.1T_max  \
# 2       0.0         15.5         14.5          3.9          3.7          1.0
# 3       0.0         15.5         14.5          3.9          3.7          1.0
# 4       0.0         15.5         14.5          3.9          3.7          1.0
# 5       0.0         15.5         14.5          3.9          3.7          1.0
# 6       0.0         15.5         14.5          3.9          3.7          1.0
#
#    Cu_3.1T_min  FM_3.2_A  Cu_3.2C_max  Cu_3.2C_min  Ni_3.2C_max  Ni_3.2C_min  \
# 2          0.8       0.0         14.0         12.0          3.7          3.5
# 3          0.8       0.0         14.0         12.0          3.7          3.5
# 4          0.8       0.0         14.0         12.0          3.7          3.5
# 5          0.8       0.0         14.0         12.0          3.7          3.5
# 6          0.8       0.0         14.0         12.0          3.7          3.5
#
#    Cu_3.2T_max  Cu_3.2T_min    Ni_rec
# 2          1.2          1.0  0.970170
# 3          1.2          1.0  0.968639
# 4          1.2          1.0  0.974205
# 5          1.2          1.0  0.973383
# 6          1.2          1.0  0.938520

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
# Определяем столбцы с пропусками
columns_with_nan = data.columns[data.isna().any()]

# Создаем новый DataFrame с этими столбцами
data_with_nan_columns = data[columns_with_nan]

# %%
data.isna().sum().sum()
# Out:
# 0
